# %%
import pandas as pd

df = pd.read_csv('datasets/class_grades.csv')
df.head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00       NaN  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
df.isnull().head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0   False       False     False    False     False  False
# 1   False       False     False    False     False  False
# 2   False       False     False     True     False  False
# 3   False        True      True    False     False  False
# 4   False       False     False    False     False  False

# %%
df.dropna().head(10)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 4        8       91.32     93.64    95.00    107.41  73.89
# 5        7       95.00     92.58    93.12     97.78  68.06
# 6        8       95.05    102.99    56.25     99.07  50.00
# 8        8       84.26     93.10    47.50     18.52  50.83
# 9        7       90.10     97.55    51.25     88.89  63.61
# 10       7       80.44     90.20    75.00     91.48  39.72
# 12       8       97.16    103.71    72.50     93.52  63.33
# 13       7       91.28     83.53    81.25     99.81  92.22

# %%
df.fillna(0).head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17     0.00     63.15  48.89
# 3       7        0.00      0.00    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00      0.00  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
df_1 = pd.read_csv('datasets/log.csv')
df_1.head()
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN

# %%
df.ffill().head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17    67.50     63.15  48.89
# 3       7       83.70     83.17    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00     99.07  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
df.bfill().head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17    49.38     63.15  48.89
# 3       7       91.32     93.64    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00     18.52  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
df_1 = df_1.reset_index()
df_1 = df_1.set_index(['time', 'user'])
df_1.head(100)
# Out:
#                    index          video  playback position paused  volume
# time       user
# 1469974424 cheryl      0     intro.html                  5  False    10.0
#            sue         1  advanced.html                 23  False    10.0
# 1469974454 cheryl      2     intro.html                  6    NaN     NaN
#            sue         3  advanced.html                 24    NaN     NaN
# 1469974484 cheryl      4     intro.html                  7    NaN     NaN
# 1469974514 cheryl      5     intro.html                  8    NaN     NaN
# 1469974524 sue         6  advanced.html                 25    NaN     NaN
# 1469974544 cheryl      7     intro.html                  9    NaN     NaN
# 1469974554 sue         8  advanced.html                 26    NaN     NaN
# 1469974574 cheryl      9     intro.html                 10    NaN     NaN
# 1469974604 cheryl     10     intro.html                 11    NaN     NaN
# ...

# %%
df_1 = df_1.set_index('time')
df_1 = df_1.sort_index()
df_1.head(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-d604323aa131> in <module>
# ----> 1 df_1 = df_1.set_index('time')
#       2 df_1 = df_1.sort_index()
#       3 df_1.head(100)
#
# ~/Documents/learn_projects/coursera-data-science/venv/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['time'] are in the columns"

# %%
df_1 = df_1.ffill()
df_1.head(100)
# Out:
#                    index          video  playback position  paused  volume
# time       user
# 1469974424 cheryl      0     intro.html                  5   False    10.0
#            sue         1  advanced.html                 23   False    10.0
# 1469974454 cheryl      2     intro.html                  6   False    10.0
#            sue         3  advanced.html                 24   False    10.0
# 1469974484 cheryl      4     intro.html                  7   False    10.0
# 1469974514 cheryl      5     intro.html                  8   False    10.0
# 1469974524 sue         6  advanced.html                 25   False    10.0
# 1469974544 cheryl      7     intro.html                  9   False    10.0
# 1469974554 sue         8  advanced.html                 26   False    10.0
# 1469974574 cheryl      9     intro.html                 10   False    10.0
# 1469974604 cheryl     10     intro.html                 11   False    10.0
# ...

# %%
df = pd.DataFrame({'A': [1, 2, 3], 
                   'B': [1, 20, 30],
                  'C': ['a', 'b', 'c']})
df.head()
# Out:
#    A   B  C
# 0  1   1  a
# 1  2  20  b
# 2  3  30  c

# %%
df.replace(1, 100).head()
# Out:
#      A    B  C
# 0  100  100  a
# 1    2   20  b
# 2    3   30  c

# %%
df.replace([1, 3], [100, 300]).head()
# Out:
#      A    B  C
# 0  100  100  a
# 1    2   20  b
# 2  300   30  c

# %%
df = pd.read_csv('datasets/log.csv') 
df.replace(".+\\.html", "webpage", regex=True).head()
# Out:
#          time    user    video  playback position paused  volume
# 0  1469974424  cheryl  webpage                  5  False    10.0
# 1  1469974454  cheryl  webpage                  6    NaN     NaN
# 2  1469974544  cheryl  webpage                  9    NaN     NaN
# 3  1469974574  cheryl  webpage                 10    NaN     NaN
# 4  1469977514     bob  webpage                  1    NaN     NaN
